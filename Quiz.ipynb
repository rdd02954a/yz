# %% [markdown]
# # Yapay Zeka'ya Giriş - Quiz

# %% [markdown]
# ## Bilgi

# %% [markdown]
# 1. Ödev dökümanın adi "Quiz_Isim_Varsaikinciisim_Soyisim" formatında olmalıdır.
# 2. Öğrencilerin amacı aşağıda verilen 3 fonksiyonun kod bloklarını verilen önerge ve örneklere göre doldurmaktır.
# 3. Aşağıdaki sorularda eğer fonksiyona yanlış/istenmeyen bir girdi değeri veriliyor ise "raise GirdiHatasi" çıktısı verilmelidir.
# 4. Quizi bitirdikten sonra quiz yükle formuna dosyanızı ipynb formatında ve yukarıda ifade edilen isimlendirme formatıyla yüklemeye özen gösteriniz.

# %% [markdown]
# ### Error Handling

# %%
# Öğrenciler bu kısmı değiştirmeyecektir.
class GirdiHatasi(Exception):
    pass

# %% [markdown]
# ### Soru 1

# %%
def buyuk_harf_kontrol(girdi: str) -> bool:
    """ Bu fonksiyona girdi olarak bir string verildiğinde büyük harf kullanım kurallarına uyulup uyulmadığını kontrol eder.
    Büyük harf kullanım kuralları:
    1: Bir kelimenin ilk harfi büyük, diğerleri küçük harf olabilir.
    2: Bir kelimenin tüm harfleri büyük harf olabilir.
    3: Bir kelimenin tüm harfleri küçük harf olabilir.

    Args:
        girdi: En az bir harften oluşan ve boşluk içermeyen bir string

    Returns:
        bool: True, False

    Example:
        girdi = "IRONMAN"
        sonuc = True

        girdi = "SpiderMan"
        sonuc = False

    """

    # ╭━━━━┳━━━┳━╮╭━┳━━━┳━╮╭━┳╮╱╱╭━━━╮
    # ┃╭╮╭╮┃╭━╮┃┃╰╯┃┃╭━╮┃┃╰╯┃┃┃╱╱┃╭━╮┃
    # ╰╯┃┃╰┫┃╱┃┃╭╮╭╮┃┃╱┃┃╭╮╭╮┃┃╱╱┃┃╱┃┃
    # ╱╱┃┃╱┃╰━╯┃┃┃┃┃┃╰━╯┃┃┃┃┃┃┃╱╭┫╰━╯┃
    # ╱╱┃┃╱┃╭━╮┃┃┃┃┃┃╭━╮┃┃┃┃┃┃╰━╯┃╭━╮┃
    # ╱╱╰╯╱╰╯╱╰┻╯╰╯╰┻╯╱╰┻╯╰╯╰┻━━━┻╯╱╰╯

    return NotImplementedError

# %% [markdown]
# ### Soru 2

# %%
def palindrom_kontrol (sayi: int) -> bool:
    """ Bu fonksiyon bir sayının palindrom olup olmadığını kontrol eder.
        Palindrom  sayılar sağdan sola ve soldan sağa aynı şekilde okunmaktadır.

    Args:
        sayi (int): kontrol yapılacak negatif olmayan sayı


    Returns:
        sonuc: bool

    Example:
        sayi: 12821
        sonuc: True

        sayi: 1223
        sonuc: False
    """

    # ╭━━━━┳━━━┳━╮╭━┳━━━┳━╮╭━┳╮╱╱╭━━━╮
    # ┃╭╮╭╮┃╭━╮┃┃╰╯┃┃╭━╮┃┃╰╯┃┃┃╱╱┃╭━╮┃
    # ╰╯┃┃╰┫┃╱┃┃╭╮╭╮┃┃╱┃┃╭╮╭╮┃┃╱╱┃┃╱┃┃
    # ╱╱┃┃╱┃╰━╯┃┃┃┃┃┃╰━╯┃┃┃┃┃┃┃╱╭┫╰━╯┃
    # ╱╱┃┃╱┃╭━╮┃┃┃┃┃┃╭━╮┃┃┃┃┃┃╰━╯┃╭━╮┃
    # ╱╱╰╯╱╰╯╱╰┻╯╰╯╰┻╯╱╰┻╯╰╯╰┻━━━┻╯╱╰╯

    return NotImplementedError

# %% [markdown]
# ### Soru 3

# %%
def yeni_palindrom_yarat (girdi: str) -> str:
    """ Girdi olarak bir sayı verildiğinde, başına gerekli eklemeleri yaparak en kısa uzunlukta olan
        yeni bir polindrom yaratır

    Args:
        girdi (str): polindrom olan veya olmayan, uzunluğu 0'dan fazla olan string


    Returns:
        sonuc (str): en kısa polindrom çıktı string

    Example:
        sayi: "bacaba"
        sonuc: "abacaba"

        sayi: "asdzxc"
        sonuc: "cxzdsasdzxc"
    """

    # ╭━━━━┳━━━┳━╮╭━┳━━━┳━╮╭━┳╮╱╱╭━━━╮
    # ┃╭╮╭╮┃╭━╮┃┃╰╯┃┃╭━╮┃┃╰╯┃┃┃╱╱┃╭━╮┃
    # ╰╯┃┃╰┫┃╱┃┃╭╮╭╮┃┃╱┃┃╭╮╭╮┃┃╱╱┃┃╱┃┃
    # ╱╱┃┃╱┃╰━╯┃┃┃┃┃┃╰━╯┃┃┃┃┃┃┃╱╭┫╰━╯┃
    # ╱╱┃┃╱┃╭━╮┃┃┃┃┃┃╭━╮┃┃┃┃┃┃╰━╯┃╭━╮┃
    # ╱╱╰╯╱╰╯╱╰┻╯╰╯╰┻╯╱╰┻╯╰╯╰┻━━━┻╯╱╰╯

    return NotImplementedError

# %% [markdown]
# # **Quizi bitirdikten sonra yukarıdaki 'Bilgi' hücresindeki yönlendirmelere göre quizi sisteme yükleyiniz! (Quiz Yükle)**
